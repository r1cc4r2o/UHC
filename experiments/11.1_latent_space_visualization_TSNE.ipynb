# %%
from google.colab import drive

drive.mount('/content/MyDrive/')
# Out:
# Mounted at /content/MyDrive/

# %%
# !pip install pytorch-lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pytorch-lightning
#   Downloading pytorch_lightning-2.0.3-py3-none-any.whl (720 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 720.6/720.6 kB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.22.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.4.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning)
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 44.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.5.0)
# Collecting lightning-utilities>=0.7.0 (from pytorch-lightning)
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning) (2.27.1)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1 (from fsspec[http]>2021.06.0->pytorch-lightning)
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 50.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.12.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch-lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch-lightning) (16.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning) (2.0.12)
# Collecting multidict<7.0,>=4.5 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning)
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 14.4 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning)
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning)
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.5 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning)
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 17.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2 (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning)
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch-lightning) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch-lightning) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch-lightning) (1.3.0)
# Installing collected packages: multidict, lightning-utilities, frozenlist, async-timeout, yarl, aiosignal, aiohttp, torchmetrics, pytorch-lightning
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 lightning-utilities-0.8.0 multidict-6.0.4 pytorch-lightning-2.0.3 torchmetrics-0.11.4 yarl-1.9.2

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pytorch_lightning as pl
import torchmetrics


class LinearWeightBlock(nn.Module):
    def __init__(self, dim_embedding = 512, n_head = 2) -> None:
        super().__init__()

        self.dim_embedding = dim_embedding

        self.linear = nn.Linear(dim_embedding, dim_embedding//16)

        self.transformer_encoder = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(d_model=dim_embedding//16, nhead=n_head), num_layers=2
        )

        self.bilinear = nn.Bilinear(dim_embedding//16, dim_embedding//16, dim_embedding//16)

        self.dropout = nn.Dropout(0.1)

        self.gelu = nn.GELU()

        self.layer_norm = nn.LayerNorm(dim_embedding//16)

    def forward(self, x):
        x = self.linear(x)
        x = self.layer_norm(x)
        x_0 = self.transformer_encoder(x)
        x = self.bilinear(x_0 + self.dropout(x_0), x)
        x = self.gelu(x)
        return x


class Classifier(nn.Module):
    def __init__(self, dim_embedding = 512, n_head = 2, n_class = 15) -> None:
        super().__init__()

        self.dim_embedding = dim_embedding
        self.n_class = n_class

        self.linear_weight_block = LinearWeightBlock(dim_embedding, n_head)

        self.flatten = nn.Flatten(start_dim=1, end_dim=- 1)

        self.linear_transformation = nn.Linear((dim_embedding//16) * 512, dim_embedding//32)

        self.layer_norm = nn.LayerNorm(dim_embedding//32)

        self.mlp = nn.Sequential(
            nn.Linear(dim_embedding//32, dim_embedding//16),
            nn.GELU(),
            nn.LayerNorm(dim_embedding//16),
            nn.Linear(dim_embedding//16, n_class)
        )

    def forward(self, x):
        x = self.linear_weight_block(x)
        x = self.flatten(x)
        x = self.linear_transformation(x)
        x = self.layer_norm(x)
        emb = x
        x = self.mlp(x)
        return x, emb


class LitClassifier(pl.LightningModule):
    def __init__(self, dim_embedding = 512, n_head = 2, n_class = 15) -> None:
        super().__init__()

        self.model = Classifier(dim_embedding, n_head, n_class)

        self.loss = nn.CrossEntropyLoss()
        self.accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=n_class)
        self.f1 = torchmetrics.F1Score(task="multiclass",num_classes=n_class)
        self.precision = torchmetrics.Precision(task="multiclass",num_classes=n_class)
        self.recall = torchmetrics.Recall(task="multiclass",num_classes=n_class)


    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch

        # y = y.long()

        y_hat, _ = self(x)
        loss = self.loss(y_hat, y)

        self.log("train_loss", loss)
        # self.log("train_acc", torch.sum(torch.argmax(y_hat, dim=-1) == torch.argmax(y, dim=-1))/x.shape[0])
        # self.log("train_acc", self.accuracy(torch.argmax(y_hat, dim=-1),torch.argmax(y, dim=-1)))
        self.log("train_acc", self.accuracy(y_hat, y))
        self.log("train_f1", self.f1(y_hat, y))
        self.log("train_precision", self.precision(y_hat, y))
        self.log("train_recall", self.recall(y_hat, y))

        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch

        # y = y.long()

        y_hat = self(x)
        loss = self.loss(y_hat, y)

        self.log("val_loss", loss)
        # self.log("train_acc", torch.sum(torch.argmax(y_hat, dim=-1) == torch.argmax(y, dim=-1))/x.shape[0])
        # self.log("train_acc", self.accuracy(torch.argmax(y_hat, dim=-1),torch.argmax(y, dim=-1)))
        self.log("train_acc", self.accuracy(y_hat, y))
        self.log("val_f1", self.f1(y_hat, y))
        self.log("val_precision", self.precision(y_hat, y))
        self.log("val_recall", self.recall(y_hat, y))

        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=1e-3)
        scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)
        return [optimizer], [scheduler]

# %%
net = LitClassifier()

model = net.load_from_checkpoint("/content/MyDrive/MyDrive/ESM2_dataset/epoch=136-step=9042.ckpt", map_location=torch.device('cpu'))

# disable randomness, dropout, etc...
model.eval()
# Out:
# LitClassifier(
#   (model): Classifier(
#     (linear_weight_block): LinearWeightBlock(
#       (linear): Linear(in_features=512, out_features=32, bias=True)
#       (transformer_encoder): TransformerEncoder(
#         (layers): ModuleList(
#           (0-1): 2 x TransformerEncoderLayer(
#             (self_attn): MultiheadAttention(
#               (out_proj): NonDynamicallyQuantizableLinear(in_features=32, out_features=32, bias=True)
#             )
#             (linear1): Linear(in_features=32, out_features=2048, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#             (linear2): Linear(in_features=2048, out_features=32, bias=True)
#             (norm1): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (norm2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#             (dropout1): Dropout(p=0.1, inplace=False)
#             (dropout2): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (bilinear): Bilinear(in1_features=32, in2_features=32, out_features=32, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (gelu): GELU(approximate='none')
#       (layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (linear_transformation): Linear(in_features=16384, out_features=16, bias=True)
#     (layer_norm): LayerNorm((16,), eps=1e-05, elementwise_affine=True)
#     (mlp): Sequential(
#       (0): Linear(in_features=16, out_features=32, bias=True)
#       (1): GELU(approximate='none')
#       (2): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=32, out_features=15, bias=True)
#     )
#   )
#   (loss): CrossEntropyLoss()
#   (accuracy): MulticlassAccuracy()
#   (f1): MulticlassF1Score()
#   (precision): MulticlassPrecision()
#   (recall): MulticlassRecall()
# )

# %%
X_embedding_dataset_AVG = torch.load('/content/MyDrive/MyDrive/ESM2_dataset/esm_X_embedding_dataset_AVG.pt').type(torch.float32)

X_embedding_dataset_AVG.shape
# Out:
# torch.Size([5250, 512, 512])

# %%
# preprocess the pred in batches
start_end = torch.linspace(0, 5250, 100, dtype=torch.int16)

for m, M in zip(start_end[:-1].tolist(), start_end[1:].tolist()):

  pred = model(X_embedding_dataset_AVG[m:M])

  torch.save(pred, f'/content/MyDrive/MyDrive/ESM2_dataset/pred_emb{m}_{M}.pt')

  del pred

# %%
del X_embedding_dataset_AVG

# %%
import glob
import numpy as np

file_name = glob.glob('/content/MyDrive/MyDrive/ESM2_dataset/pred_emb*')

pred_labels = []
pred_embeds = []

for _file_ in file_name:

  print(_file_)

  labels, embeds = torch.load(_file_)

  # append embeds
  for e in embeds:
    pred_embeds.append(e.detach().numpy())

  # append labels
  for l in labels:
    pred_labels.append(l.detach().numpy())



pred_embeds = torch.tensor(np.array(pred_embeds))
pred_labels = torch.tensor(np.array(pred_labels))

print(pred_embeds.shape)
print(pred_labels.shape)
# Out:
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb0_53.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb53_106.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb106_159.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb159_212.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb212_265.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb265_318.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb318_371.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb371_424.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb424_477.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb477_530.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb530_583.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb583_636.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb636_689.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb689_742.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb742_795.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb795_848.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb848_901.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb901_954.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb954_1007.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1007_1060.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1060_1113.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1113_1166.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1166_1219.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1219_1272.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1272_1325.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1325_1378.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1378_1431.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1431_1484.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1484_1537.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1537_1590.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1590_1643.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1643_1696.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1696_1750.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1750_1803.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1803_1856.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1856_1909.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1909_1962.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb1962_2015.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2015_2068.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2068_2121.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2121_2174.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2174_2227.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2227_2280.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2280_2333.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2333_2386.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2386_2439.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2439_2492.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2492_2545.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2545_2598.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2598_2651.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2651_2704.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2704_2757.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2757_2810.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2810_2863.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2863_2916.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2916_2969.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb2969_3022.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3022_3075.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3075_3128.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3128_3181.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3181_3234.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3234_3287.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3287_3340.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3340_3393.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3393_3446.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3446_3500.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3500_3553.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3553_3606.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3606_3659.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3659_3712.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3712_3765.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3765_3818.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3818_3871.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3871_3924.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3924_3977.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb3977_4030.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4030_4083.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4083_4136.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4136_4189.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4189_4242.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4242_4295.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4295_4348.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4348_4401.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4401_4454.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4454_4507.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4507_4560.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4560_4613.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4613_4666.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4666_4719.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4719_4772.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4772_4825.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4825_4878.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4878_4931.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4931_4984.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb4984_5037.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb5037_5090.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb5090_5143.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb5143_5196.pt
# /content/MyDrive/MyDrive/ESM2_dataset/pred_emb5196_5250.pt
# torch.Size([5250, 16])
# torch.Size([5250, 15])

# %%
torch.save(pred_embeds, '/content/MyDrive/MyDrive/ESM2_dataset/pred_emb.pt')
torch.save(pred_labels, '/content/MyDrive/MyDrive/ESM2_dataset/pred_label.pt')

# %%
labels = torch.argmax(pred_labels, dim=-1)

# %%
import numpy as np
from sklearn.manifold import TSNE


X = np.array(pred_embeds)
X_embedded = TSNE(n_components=2, learning_rate='auto',
                  init='random', perplexity=30).fit_transform(X)

X_embedded.shape
# Out:
# (5250, 2)

# %%
import numpy as np
from matplotlib import pyplot as plt

x = X_embedded[:, 0]
y = X_embedded[:, 1]

yy = []
label = 0
conta = 0
for i in range(5250):
  if conta == 350:
    conta = 0
    label = label + 1
  yy.append(label)
  conta = conta + 1

y_embedding_dataset = torch.tensor(yy)

del yy

# group = np.array(labels)

group = np.array(y_embedding_dataset)

cdict = {0: 'black',
         1: 'red',
         2: 'blue',
         3: 'green',
         4: 'orange',
         5: 'pink',
         6: 'purple',
         7: 'gray',
         8: 'olive',
         9: 'cyan',
         10: 'khaki',
         11: 'orchid',
         12: 'salmon',
         13: 'chartreuse',
         14: 'beige'}

plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(16,16),dpi=400)
for g in np.unique(group):
    ix = np.where(group == g)
    ax.scatter(x[ix], y[ix], c = cdict[g], label = g, s = 100)

plt.title('Partitioning of proteins based on their distinct functions within a latent space')
ax.legend()
plt.show()
